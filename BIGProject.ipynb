# %%
import bs4
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen
import requests

news_url="https://news.google.com/rss"
Client=urlopen(news_url)
xml_page=Client.read()
Client.close()
soup_page=soup(xml_page,"xml")
news_list=soup_page.findAll("item")
# Print news title, url and publish date
urls=[]
for news in news_list:
    print(news.title.text)
    print(news.link.text)
    print(news.pubDate.text)
    print("-"*60)
    urls.append(news.link.text)
for url in urls:
    source_code=requests.get(url)
    plain_text=source_code.text
    soup_object=soup(plain_text,"xml")
    for text in soup_object.findAll("p"):
        print(text)
# Out:
# Trump Urges Sessions To End Mueller Investigation, As Manafort Trial Day 2 Continues
# https://www.npr.org/2018/08/01/634439965/on-manafort-trial-day-two-a-central-question-how-much-power-did-rick-gates-wield
# Wed, 1 Aug 2018 19:18:50 GMT
# ------------------------------------------------------------
# Former President Barack Obama endorses 81 candidates in US midterms, says he's 'eager' to get involved
# https://www.usatoday.com/story/news/politics/2018/08/01/former-president-barack-obama-endorses-81-candidates-2018-midterms/879720002/
# Wed, 1 Aug 2018 17:57:15 GMT
# ------------------------------------------------------------
# Suspect identified in murder of George HW Bush's former doctor
# http://www.foxnews.com/us/2018/08/01/suspect-identified-in-murder-former-george-h-w-bush-doctor.html
# Wed, 1 Aug 2018 19:44:37 GMT
# ------------------------------------------------------------
# ...

# %%
import bs4
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen
import requests
def spider(companies):
    for company in companies:
        news_url="https://news.google.com/search?q="+str(company)+"&hl=de&gl=DE&ceid=DE%3Ade"
        #there is a problem with the link
        source_code=requests.get(news_url)
        plain_text=source_code.text
        soup_object=soup(xml_page,"xml")
        for link in soup_object.findAll("a",{"class":"item name"}):
            href=news_url +link.get("href")
            print(href)
            #access href and crawl the html for html text
spider(["facebook","google"])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
#
# <?xml version="1.0" encoding="utf-8"?>
